# %%
# Create volume
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.default.food_inspections")

# %%
## Check for uploads
dbutils.fs.ls("/Volumes/workspace/default/food_inspections/")
